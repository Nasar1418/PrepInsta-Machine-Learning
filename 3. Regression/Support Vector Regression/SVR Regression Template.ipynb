# %% [markdown]
# # Support Vector Regression (SVR)

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing Data Set

# %%
dataset = pd.read_csv('Accenture Salary DataSet.csv')
x = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ##Reshaping

# %%
y=y.reshape(len(y),1)
print(y)
# Out:
# [[  17000]
#  [  27000]
#  [  40000]
#  [  65000]
#  [ 100000]
#  [ 150000]
#  [ 250000]
#  [ 400000]
#  [ 650000]
#  [1000000]
#  [1800000]
#  [4000000]]

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
sc_y=StandardScaler()
x=sc_x.fit_transform(x)
y=sc_y.fit_transform(y)

# %%
print(x)
# Out:
# [[-1.52973232]
#  [-1.25977956]
#  [-0.9898268 ]
#  [-0.71987403]
#  [-0.44992127]
#  [-0.17996851]
#  [ 0.08998425]
#  [ 0.35993702]
#  [ 0.62988978]
#  [ 0.89984254]
#  [ 1.43974807]
#  [ 1.70970083]]

# %% [markdown]
# ## Training the SVR model on the whole dataset

# %%
from sklearn.svm import SVR
regressor=SVR(kernel='rbf')
regressor.fit(x,y)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %% [markdown]
# ## Predicting a new result

# %%
new_x=sc_x.transform([[6.5]])
y_pred=regressor.predict(new_x)
print(y_pred)
# Out:
# [-0.36788056]

# %%
print(sc_y.inverse_transform(y_pred.reshape(-1, 1)))
# Out:
# [[298252.57347613]]

# %%
y_pred=regressor.predict(x)
print(y_pred)
# Out:
# [-0.51997656 -0.53589004 -0.51446569 -0.48013351 -0.44569124 -0.40155912
#  -0.32132488 -0.17642825  0.04789058  0.33815237  0.89106499  1.00649317]

# %%
y_pred=sc_y.inverse_transform(y_pred.reshape(-1, 1))
print(y_pred)
# Out:
# [[ 128743.83347651]
#  [ 111008.4985535 ]
#  [ 134885.61636129]
#  [ 173148.3263461 ]
#  [ 211533.72652175]
#  [ 260718.31960367]
#  [ 350138.19131643]
#  [ 511623.3319164 ]
#  [ 761623.34520807]
#  [1085115.80588494]
#  [1701328.71118636]
#  [1829971.70446991]]

# %% [markdown]
# ## Visualising the SVR results

# %%
x=sc_x.inverse_transform(x)
y=sc_y.inverse_transform(y)

# %%
plt.scatter(x,y,color='red')
plt.plot(x,y_pred,color='blue')
plt.title("SVR")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()
