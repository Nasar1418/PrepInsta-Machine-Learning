# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Data Set

# %%
data=pd.read_csv('/content/RBC in Humans Polynomial Regres.csv.csv')
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=6)
x_poly=poly_reg.fit_transform(x)

# %%
linear_reg2=LinearRegression()
linear_reg2.fit(x_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(x,y,color='red')
plt.plot(x,lin_reg.predict(x),color='blue')
plt.xlabel("Age")
plt.ylabel("RBC")
plt.title("RBC in Humans")
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
x_grid=np.arange(min(x),max(x),0.1)
x_grid=x_grid.reshape(len(x_grid),1)
x_grid_poly=poly_reg.fit_transform(x_grid)
plt.scatter(x,y,color='red')
plt.plot(x_grid,linear_reg2.predict(x_grid_poly),color='blue')
plt.xlabel("Age")
plt.ylabel("RBC")
plt.title("RBC in Humans")
plt.show()
# Out:
# /tmp/ipython-input-686491519.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid=np.arange(min(x),max(x),0.1)

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([1980.15863901])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
linear_reg2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([878.06765741])
